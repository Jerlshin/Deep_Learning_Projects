# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))  


ax[0].imshow(plt.imread('./DDPM.png'))
ax[0].set_title("Sampled with DDPM")

ax[1].imshow(plt.imread('./DDIM.png'))
ax[1].set_title("Sampled with DDIM")
plt.tight_layout()
plt.show()
